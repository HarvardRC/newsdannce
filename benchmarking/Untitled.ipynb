# %%
import caldannce
from caldannce.calibration_data import CameraParams
import numpy as np
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
# K=np.array([
#     [2289.569077689851,0,0],
#     [0,2287.243180527006,0],
#     [924.4206944023736,560.9839654208081,1]
#   ])
# r=np.array([
#     [0.533387846178686,0.27152545798349875,-0.8011063170489382],
#     [0.845869629413075,-0.17279157919469537,0.5046262381168767],
#     [-0.001405555210557352,-0.9467930057970723,-0.32184006678518995]
#   ])
# # r_distort=np.array([-0.07358087888239587,0.08670589794235148])

# r_distort=np.array([0,0])
# # t_distort=np.array([-0.0024658828546337435,-0.0014882729052280038])
# t_distort=np.array([0,0])
# t=np.array([[-63.486804007198934],[74.55726515027474],[1075.2393163801505]])
# params = CameraParams(camera_matrix=K, r_distort=r_distort,t_distort=t_distort,translation_vector=t,rotation_matrix=r)

# %%
param_list = CameraParams.load_from_dannce_mat_file("/net/holy-nfsisilon/ifs/rc_labs/olveczky_lab_tier1/Lab/dannce_rig2/data/M1-M7_photometry/Alone/Day2_wk2/240625_143814_M5/20240925_181406_DANNCE_Label3D_dannce.mat")

# %%
# %matplotlib widget

# %%
w0 = np.array([324.90451808943556,135.62236364378356,52.73339566383596])

# %%
# Create a new figure for the plot
fig = plt.figure()

# Add a 3D subplot to the figure
ax = fig.add_subplot(111, projection='3d')

# Define the coordinates of the point
x = [w0[0]]  # X-coordinate
y = [w0[1]]  # Y-coordinate
z = [w0[2]]  # Z-coordinate

# Plot the point in 3D space
ax.scatter(x, y, z, c='r', marker='o')

for i in range(6):
    t = param_list[i].translation_vector
    ax.scatter([t[0]], [t[1]], [t[2]], c='r', marker='x')


# Set labels for the axes
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

# Show the plot
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
